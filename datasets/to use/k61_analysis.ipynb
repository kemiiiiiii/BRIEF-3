# %%
import pandas as pd
# Import Seaborn 
import seaborn as sns
#Import Matplot Lib
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/kemi/Documents/GitHub/Machine Learning/BRIEF 3/datasets/to use/kc61_referral_outcomes.csv')
df.shape
# Out:
# (32, 19)

# %%
df
# Out:
#    CollectionYearRange Parent_Org_Code           Parent_Org_Name   Org_Code  \
# 0              2022-23       E92000001                   England  E92000001
# 1              2022-23       E92000001                   England  E92000001
# 2              2023-24       E92000001                   England  E92000001
# 3              2023-24       E92000001                   England  E92000001
# 4              2022-23              N1  North East and Yorkshire         N1
# 5              2022-23              N1  North East and Yorkshire         N1
# 6              2022-23              N2                North West         N2
# 7              2022-23              N2                North West         N2
# 8              2022-23              N3                  Midlands         N3
# 9              2022-23              N3                  Midlands         N3
# 10             2022-23              N4           East of England         N4
# ...

# %%
df.value_counts().sum()
# Out:
# np.int64(32)

# %%
df.shape
# Out:
# (32, 19)

# %%
df.columns.values.tolist()
# Out:
# ['CollectionYearRange',
#  'Parent_Org_Code',
#  'Parent_Org_Name',
#  'Org_Code',
#  'Org_Name',
#  'Org_Type',
#  'Referral_type',
#  'Part',
#  'All_samples',
#  'Cervical_cancer',
#  'CIN3_and_adeno_in_situ',
#  'CIN2',
#  'CIN1',
#  'HPV_only',
#  'No_CIN_No_HPV',
#  'Non_cerv_cancer_detected',
#  'Seen_Colp_result_unknown',
#  'Inadequate_biopsy',
#  'Seen_Colp_NAD_no_biop']

# %%
dfcropped = df[['CollectionYearRange',
 'Org_Name',
 'Org_Type',
 'Referral_type',
 'All_samples',
 'Cervical_cancer',
 'HPV_only',
 'No_CIN_No_HPV',
 'Seen_Colp_result_unknown',
 'Inadequate_biopsy',
 'Seen_Colp_NAD_no_biop']]

# %%
dfcropped.head(5)
# Out:
#   CollectionYearRange                  Org_Name  Org_Type  \
# 0             2022-23                   England  National
# 1             2022-23                   England  National
# 2             2023-24                   England  National
# 3             2023-24                   England  National
# 4             2022-23  North East and Yorkshire    Region
#
#              Referral_type  All_samples  Cervical_cancer  HPV_only  \
# 0    category_1_8_3_result     132391.0             99.0   17440.0
# 1  category_7_4_5_6_result      33117.0            959.0    1460.0
# 2    category_1_8_3_result      31222.0             22.0    4022.0
# 3  category_7_4_5_6_result       6595.0            222.0     271.0
# 4    category_1_8_3_result      17513.0             12.0    1556.0
#
#    No_CIN_No_HPV  Seen_Colp_result_unknown  Inadequate_biopsy  \
# 0         8006.0                    1183.0             1256.0
# 1          909.0                      66.0               51.0
# ...

# %% [markdown]
# ## 2022-23 entries

# %%
# split 22-23 
df_22_23 = dfcropped[dfcropped['CollectionYearRange'] == '2022-23']

# %%
df_22_23
# Out:
#    CollectionYearRange                  Org_Name  Org_Type  \
# 0              2022-23                   England  National
# 1              2022-23                   England  National
# 4              2022-23  North East and Yorkshire    Region
# 5              2022-23  North East and Yorkshire    Region
# 6              2022-23                North West    Region
# 7              2022-23                North West    Region
# 8              2022-23                  Midlands    Region
# 9              2022-23                  Midlands    Region
# 10             2022-23           East of England    Region
# 11             2022-23           East of England    Region
# 12             2022-23                    London    Region
# 13             2022-23                    London    Region
# 14             2022-23                South East    Region
# 15             2022-23                South East    Region
# 16             2022-23                South West    Region
# ...

# %%
df_22_23.describe(include='all')
# Out:
#        CollectionYearRange Org_Name Org_Type          Referral_type  \
# count                   16       16       16                     16
# unique                   1        8        2                      2
# top                2022-23  England   Region  category_1_8_3_result
# freq                    16        2       14                      8
# mean                   NaN      NaN      NaN                    NaN
# std                    NaN      NaN      NaN                    NaN
# min                    NaN      NaN      NaN                    NaN
# 25%                    NaN      NaN      NaN                    NaN
# 50%                    NaN      NaN      NaN                    NaN
# 75%                    NaN      NaN      NaN                    NaN
# max                    NaN      NaN      NaN                    NaN
#
#           All_samples  Cervical_cancer      HPV_only  No_CIN_No_HPV  \
# count       16.000000        16.000000     16.000000      16.000000
# ...

# %% [markdown]
# #### 2022-23 max CC diagnosis

# %%
# see full max rows
maxrow_22_23 = df_22_23[df_22_23['Cervical_cancer'] == df_22_23['Cervical_cancer'].max()]
maxrow_22_23[['CollectionYearRange',
 'Org_Name',
 'Org_Type',
 'Referral_type',
 'All_samples',
 'Cervical_cancer',
 'HPV_only',
 'No_CIN_No_HPV',
 'Seen_Colp_result_unknown',
 'Inadequate_biopsy',
 'Seen_Colp_NAD_no_biop']]
# Out:
#   CollectionYearRange Org_Name  Org_Type            Referral_type  \
# 1             2022-23  England  National  category_7_4_5_6_result
#
#    All_samples  Cervical_cancer  HPV_only  No_CIN_No_HPV  \
# 1      33117.0            959.0    1460.0          909.0
#
#    Seen_Colp_result_unknown  Inadequate_biopsy  Seen_Colp_NAD_no_biop
# 1                      66.0               51.0                  452.0

# %% [markdown]
# #### 2022-23 min CC diagnosis

# %%
# see full max rows
minrow_22_23 = df_22_23[df_22_23['Cervical_cancer'] == df_22_23['Cervical_cancer'].min()]
minrow_22_23[['CollectionYearRange',
 'Org_Name',
 'Org_Type',
 'Referral_type',
 'All_samples',
 'Cervical_cancer',
 'HPV_only',
 'No_CIN_No_HPV',
 'Seen_Colp_result_unknown',
 'Inadequate_biopsy',
 'Seen_Colp_NAD_no_biop']]
# Out:
#    CollectionYearRange    Org_Name Org_Type          Referral_type  \
# 16             2022-23  South West   Region  category_1_8_3_result
#
#     All_samples  Cervical_cancer  HPV_only  No_CIN_No_HPV  \
# 16       7206.0              7.0    1417.0          485.0
#
#     Seen_Colp_result_unknown  Inadequate_biopsy  Seen_Colp_NAD_no_biop
# 16                      10.0               72.0                 1745.0

# %% [markdown]
# #### 2022-23 max HPV diagnosis

# %%
# see full max rows
maxrow_22_23_HPV = df_22_23[df_22_23['HPV_only'] == df_22_23['HPV_only'].max()]
maxrow_22_23_HPV[['CollectionYearRange',
 'Org_Name',
 'Org_Type',
 'Referral_type',
 'All_samples',
 'Cervical_cancer',
 'HPV_only',
 'No_CIN_No_HPV',
 'Seen_Colp_result_unknown',
 'Inadequate_biopsy',
 'Seen_Colp_NAD_no_biop']]
# Out:
#   CollectionYearRange Org_Name  Org_Type          Referral_type  All_samples  \
# 0             2022-23  England  National  category_1_8_3_result     132391.0
#
#    Cervical_cancer  HPV_only  No_CIN_No_HPV  Seen_Colp_result_unknown  \
# 0             99.0   17440.0         8006.0                    1183.0
#
#    Inadequate_biopsy  Seen_Colp_NAD_no_biop
# 0             1256.0                56966.0

# %% [markdown]
# #### 2022-23 min HPV diagnosis

# %%
# see full min rows
minrow_22_23_HPV = df_22_23[df_22_23['HPV_only'] == df_22_23['HPV_only'].min()]
minrow_22_23_HPV[['CollectionYearRange',
 'Org_Name',
 'Org_Type',
 'Referral_type',
 'All_samples',
 'Cervical_cancer',
 'HPV_only',
 'No_CIN_No_HPV',
 'Seen_Colp_result_unknown',
 'Inadequate_biopsy',
 'Seen_Colp_NAD_no_biop']]
# Out:
#    CollectionYearRange    Org_Name Org_Type            Referral_type  \
# 17             2022-23  South West   Region  category_7_4_5_6_result
#
#     All_samples  Cervical_cancer  HPV_only  No_CIN_No_HPV  \
# 17       1860.0             71.0      31.0           26.0
#
#     Seen_Colp_result_unknown  Inadequate_biopsy  Seen_Colp_NAD_no_biop
# 17                       0.0                1.0                    9.0

# %% [markdown]
# #### 2022-23 max 0 diagnosis

# %%
maxrow_22_23_0_diagnosis = df_22_23[df_22_23['No_CIN_No_HPV'] == df_22_23['No_CIN_No_HPV'].max()]
maxrow_22_23_0_diagnosis [['CollectionYearRange',
 'Org_Name',
 'Org_Type',
 'Referral_type',
 'All_samples',
 'Cervical_cancer',
 'HPV_only',
 'No_CIN_No_HPV',
 'Seen_Colp_result_unknown',
 'Inadequate_biopsy',
 'Seen_Colp_NAD_no_biop']]
# Out:
#   CollectionYearRange Org_Name  Org_Type          Referral_type  All_samples  \
# 0             2022-23  England  National  category_1_8_3_result     132391.0
#
#    Cervical_cancer  HPV_only  No_CIN_No_HPV  Seen_Colp_result_unknown  \
# 0             99.0   17440.0         8006.0                    1183.0
#
#    Inadequate_biopsy  Seen_Colp_NAD_no_biop
# 0             1256.0                56966.0

# %% [markdown]
# #### 2022-23 min 0 diagnosis

# %%
minrow_22_23_0_diagnosis = df_22_23[df_22_23['No_CIN_No_HPV'] == df_22_23['No_CIN_No_HPV'].min()]
minrow_22_23_0_diagnosis [['CollectionYearRange',
 'Org_Name',
 'Org_Type',
 'Referral_type',
 'All_samples',
 'Cervical_cancer',
 'HPV_only',
 'No_CIN_No_HPV',
 'Seen_Colp_result_unknown',
 'Inadequate_biopsy',
 'Seen_Colp_NAD_no_biop']]
# Out:
#    CollectionYearRange    Org_Name Org_Type            Referral_type  \
# 17             2022-23  South West   Region  category_7_4_5_6_result
#
#     All_samples  Cervical_cancer  HPV_only  No_CIN_No_HPV  \
# 17       1860.0             71.0      31.0           26.0
#
#     Seen_Colp_result_unknown  Inadequate_biopsy  Seen_Colp_NAD_no_biop
# 17                       0.0                1.0                    9.0

# %% [markdown]
# #### 2022-23 highest sample count

# %%
maxrow_22_23_sample = df_22_23[df_22_23['All_samples'] == df_22_23['All_samples'].max()]
maxrow_22_23_sample[['CollectionYearRange',
 'Org_Name',
 'Org_Type',
 'Referral_type',
 'All_samples',
 'Cervical_cancer',
 'HPV_only',
 'No_CIN_No_HPV',
 'Seen_Colp_result_unknown',
 'Inadequate_biopsy',
 'Seen_Colp_NAD_no_biop']]
# Out:
#   CollectionYearRange Org_Name  Org_Type          Referral_type  All_samples  \
# 0             2022-23  England  National  category_1_8_3_result     132391.0
#
#    Cervical_cancer  HPV_only  No_CIN_No_HPV  Seen_Colp_result_unknown  \
# 0             99.0   17440.0         8006.0                    1183.0
#
#    Inadequate_biopsy  Seen_Colp_NAD_no_biop
# 0             1256.0                56966.0

# %% [markdown]
# #### 2022-23 lowest sample count

# %%
minrow_22_23_sample = df_22_23[df_22_23['All_samples'] == df_22_23['All_samples'].min()]
minrow_22_23_sample[['CollectionYearRange',
 'Org_Name',
 'Org_Type',
 'Referral_type',
 'All_samples',
 'Cervical_cancer',
 'HPV_only',
 'No_CIN_No_HPV',
 'Seen_Colp_result_unknown',
 'Inadequate_biopsy',
 'Seen_Colp_NAD_no_biop']]
# Out:
#    CollectionYearRange    Org_Name Org_Type            Referral_type  \
# 17             2022-23  South West   Region  category_7_4_5_6_result
#
#     All_samples  Cervical_cancer  HPV_only  No_CIN_No_HPV  \
# 17       1860.0             71.0      31.0           26.0
#
#     Seen_Colp_result_unknown  Inadequate_biopsy  Seen_Colp_NAD_no_biop
# 17                       0.0                1.0                    9.0

# %% [markdown]
# ## 2023-24 entries

# %%
# split 23-24 

df_23_24 = dfcropped[dfcropped['CollectionYearRange']== '2023-24']

# %%
df_23_24
# Out:
#    CollectionYearRange                  Org_Name  Org_Type  \
# 2              2023-24                   England  National
# 3              2023-24                   England  National
# 18             2023-24  North East and Yorkshire    Region
# 19             2023-24  North East and Yorkshire    Region
# 20             2023-24                North West    Region
# 21             2023-24                North West    Region
# 22             2023-24                  Midlands    Region
# 23             2023-24                  Midlands    Region
# 24             2023-24           East of England    Region
# 25             2023-24           East of England    Region
# 26             2023-24                    London    Region
# 27             2023-24                    London    Region
# 28             2023-24                South East    Region
# 29             2023-24                South East    Region
# 30             2023-24                South West    Region
# ...

# %%
df_23_24.describe(include='all')
# Out:
#        CollectionYearRange Org_Name Org_Type          Referral_type  \
# count                   16       16       16                     16
# unique                   1        8        2                      2
# top                2023-24  England   Region  category_1_8_3_result
# freq                    16        2       14                      8
# mean                   NaN      NaN      NaN                    NaN
# std                    NaN      NaN      NaN                    NaN
# min                    NaN      NaN      NaN                    NaN
# 25%                    NaN      NaN      NaN                    NaN
# 50%                    NaN      NaN      NaN                    NaN
# 75%                    NaN      NaN      NaN                    NaN
# max                    NaN      NaN      NaN                    NaN
#
#          All_samples  Cervical_cancer    HPV_only  No_CIN_No_HPV  \
# count      16.000000        16.000000    16.00000      16.000000
# ...

# %% [markdown]
# #### 2023-24 max CC diagnosis

# %%
# see full max rows
maxrow_23_24 = df_23_24[df_23_24['Cervical_cancer'] == df_23_24['Cervical_cancer'].max()]
maxrow_23_24[['CollectionYearRange',
 'Org_Name',
 'Org_Type',
 'Referral_type',
 'All_samples',
 'Cervical_cancer',
 'HPV_only',
 'No_CIN_No_HPV',
 'Seen_Colp_result_unknown',
 'Inadequate_biopsy',
 'Seen_Colp_NAD_no_biop']]
# Out:
#   CollectionYearRange Org_Name  Org_Type            Referral_type  \
# 3             2023-24  England  National  category_7_4_5_6_result
#
#    All_samples  Cervical_cancer  HPV_only  No_CIN_No_HPV  \
# 3       6595.0            222.0     271.0          181.0
#
#    Seen_Colp_result_unknown  Inadequate_biopsy  Seen_Colp_NAD_no_biop
# 3                      18.0               13.0                  119.0

# %% [markdown]
# #### 2023-24 min CC diagnosis

# %%
# see full min rows
minrow_23_24 = df_23_24[df_23_24['Cervical_cancer'] == df_23_24['Cervical_cancer'].min()]
minrow_23_24[['CollectionYearRange',
 'Org_Name',
 'Org_Type',
 'Referral_type',
 'All_samples',
 'Cervical_cancer',
 'HPV_only',
 'No_CIN_No_HPV',
 'Seen_Colp_result_unknown',
 'Inadequate_biopsy',
 'Seen_Colp_NAD_no_biop']]
# Out:
#    CollectionYearRange                  Org_Name Org_Type  \
# 18             2023-24  North East and Yorkshire   Region
# 22             2023-24                  Midlands   Region
# 30             2023-24                South West   Region
#
#             Referral_type  All_samples  Cervical_cancer  HPV_only  \
# 18  category_1_8_3_result       3877.0              2.0     323.0
# 22  category_1_8_3_result       4548.0              2.0     472.0
# 30  category_1_8_3_result       1695.0              2.0     338.0
#
#     No_CIN_No_HPV  Seen_Colp_result_unknown  Inadequate_biopsy  \
# 18          249.0                       0.0               34.0
# 22          299.0                      47.0               47.0
# 30           89.0                       0.0               10.0
#
#     Seen_Colp_NAD_no_biop
# 18                 2097.0
# 22                 2047.0
# 30                  420.0

# %% [markdown]
# #### 2023-24 max HPV diagnosis

# %%
# see full max rows
maxrow_23_24_HPV = df_23_24[df_23_24['HPV_only'] == df_23_24['HPV_only'].max()]
maxrow_23_24_HPV[['CollectionYearRange',
 'Org_Name',
 'Org_Type',
 'Referral_type',
 'All_samples',
 'Cervical_cancer',
 'HPV_only',
 'No_CIN_No_HPV',
 'Seen_Colp_result_unknown',
 'Inadequate_biopsy',
 'Seen_Colp_NAD_no_biop']]
# Out:
#   CollectionYearRange Org_Name  Org_Type          Referral_type  All_samples  \
# 2             2023-24  England  National  category_1_8_3_result      31222.0
#
#    Cervical_cancer  HPV_only  No_CIN_No_HPV  Seen_Colp_result_unknown  \
# 2             22.0    4022.0         1763.0                     122.0
#
#    Inadequate_biopsy  Seen_Colp_NAD_no_biop
# 2              293.0                14037.0

# %% [markdown]
# #### 2023-24 min HPV diagnosis

# %%
# see full min rows
minrow_23_24_HPV = df_23_24[df_23_24['HPV_only'] == df_23_24['HPV_only'].min()]
minrow_23_24_HPV[['CollectionYearRange',
 'Org_Name',
 'Org_Type',
 'Referral_type',
 'All_samples',
 'Cervical_cancer',
 'HPV_only',
 'No_CIN_No_HPV',
 'Seen_Colp_result_unknown',
 'Inadequate_biopsy',
 'Seen_Colp_NAD_no_biop']]
# Out:
#    CollectionYearRange    Org_Name Org_Type            Referral_type  \
# 31             2023-24  South West   Region  category_7_4_5_6_result
#
#     All_samples  Cervical_cancer  HPV_only  No_CIN_No_HPV  \
# 31        417.0             20.0      14.0            1.0
#
#     Seen_Colp_result_unknown  Inadequate_biopsy  Seen_Colp_NAD_no_biop
# 31                       0.0                1.0                    0.0

# %% [markdown]
# #### 2023-24 max 0 diagnosis

# %%
maxrow_23_24_0_diagnosis = df_23_24[df_23_24['No_CIN_No_HPV'] == df_23_24['No_CIN_No_HPV'].max()]
maxrow_23_24_0_diagnosis [['CollectionYearRange',
 'Org_Name',
 'Org_Type',
 'Referral_type',
 'All_samples',
 'Cervical_cancer',
 'HPV_only',
 'No_CIN_No_HPV',
 'Seen_Colp_result_unknown',
 'Inadequate_biopsy',
 'Seen_Colp_NAD_no_biop']]
# Out:
#   CollectionYearRange Org_Name  Org_Type          Referral_type  All_samples  \
# 2             2023-24  England  National  category_1_8_3_result      31222.0
#
#    Cervical_cancer  HPV_only  No_CIN_No_HPV  Seen_Colp_result_unknown  \
# 2             22.0    4022.0         1763.0                     122.0
#
#    Inadequate_biopsy  Seen_Colp_NAD_no_biop
# 2              293.0                14037.0

# %% [markdown]
# #### 2023-24 min 0 diagnosis

# %%
minrow_23_24_0_diagnosis = df_23_24[df_23_24['No_CIN_No_HPV'] == df_23_24['No_CIN_No_HPV'].min()]
minrow_23_24_0_diagnosis [['CollectionYearRange',
 'Org_Name',
 'Org_Type',
 'Referral_type',
 'All_samples',
 'Cervical_cancer',
 'HPV_only',
 'No_CIN_No_HPV',
 'Seen_Colp_result_unknown',
 'Inadequate_biopsy',
 'Seen_Colp_NAD_no_biop']]
# Out:
#    CollectionYearRange    Org_Name Org_Type            Referral_type  \
# 31             2023-24  South West   Region  category_7_4_5_6_result
#
#     All_samples  Cervical_cancer  HPV_only  No_CIN_No_HPV  \
# 31        417.0             20.0      14.0            1.0
#
#     Seen_Colp_result_unknown  Inadequate_biopsy  Seen_Colp_NAD_no_biop
# 31                       0.0                1.0                    0.0

# %% [markdown]
# #### 2023-24 highest sample count

# %%
maxrow_23_24_sample = df_23_24[df_23_24['All_samples'] == df_23_24['All_samples'].max()]
maxrow_23_24_sample[['CollectionYearRange',
 'Org_Name',
 'Org_Type',
 'Referral_type',
 'All_samples',
 'Cervical_cancer',
 'HPV_only',
 'No_CIN_No_HPV',
 'Seen_Colp_result_unknown',
 'Inadequate_biopsy',
 'Seen_Colp_NAD_no_biop']]
# Out:
#   CollectionYearRange Org_Name  Org_Type          Referral_type  All_samples  \
# 2             2023-24  England  National  category_1_8_3_result      31222.0
#
#    Cervical_cancer  HPV_only  No_CIN_No_HPV  Seen_Colp_result_unknown  \
# 2             22.0    4022.0         1763.0                     122.0
#
#    Inadequate_biopsy  Seen_Colp_NAD_no_biop
# 2              293.0                14037.0

# %% [markdown]
# #### 2023-24 lowest sample count

# %%
minrow_23_24_sample = df_23_24[df_23_24['All_samples'] == df_23_24['All_samples'].min()]
minrow_23_24_sample[['CollectionYearRange',
 'Org_Name',
 'Org_Type',
 'Referral_type',
 'All_samples',
 'Cervical_cancer',
 'HPV_only',
 'No_CIN_No_HPV',
 'Seen_Colp_result_unknown',
 'Inadequate_biopsy',
 'Seen_Colp_NAD_no_biop']]
# Out:
#    CollectionYearRange    Org_Name Org_Type            Referral_type  \
# 31             2023-24  South West   Region  category_7_4_5_6_result
#
#     All_samples  Cervical_cancer  HPV_only  No_CIN_No_HPV  \
# 31        417.0             20.0      14.0            1.0
#
#     Seen_Colp_result_unknown  Inadequate_biopsy  Seen_Colp_NAD_no_biop
# 31                       0.0                1.0                    0.0
