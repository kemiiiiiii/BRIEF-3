# %%
import pandas as pd
# Import Seaborn 
import seaborn as sns
#Import Matplot Lib
import matplotlib.pyplot as plt
# Import Keplergl Library
import keplergl
# Import Plotly Library 
import plotly.express as px

# %%
df_phof = pd.read_csv('/Users/kemi/Documents/GitHub/Machine Learning/BRIEF 3/datasets/to use/dashboard-phof-quarterly-subICB-2024-25-q1.csv')

# %%
df_phof.shape
# Out:
# (2756, 17)

# %%
df_phof.head(10)
# Out:
#         Month     Quarter Region_Code               Region_Name  \
# 0  2021-06-30  2021-22 Q1   E40000009  North East and Yorkshire
# 1  2021-06-30  2021-22 Q1   E40000007           East of England
# 2  2021-06-30  2021-22 Q1   E40000009  North East and Yorkshire
# 3  2021-06-30  2021-22 Q1   E40000006                South West
# 4  2021-06-30  2021-22 Q1   E40000007           East of England
# 5  2021-06-30  2021-22 Q1   E40000005                South East
# 6  2021-06-30  2021-22 Q1   E40000008                  Midlands
# 7  2021-06-30  2021-22 Q1   E40000008                  Midlands
# 8  2021-06-30  2021-22 Q1   E40000010                North West
# 9  2021-06-30  2021-22 Q1   E40000010                North West
#
#                                          Parent_Name Org_ONS_Code Org_Code  \
# 0                  SOUTH YORKSHIRE AND BASSETLAW STP    E38000006      02P
# 1                            MID AND SOUTH ESSEX STP    E38000007      99E
# ...

# %%
df_phof.Age
# Out:
# 0       25-49
# 1       25-49
# 2       25-49
# 3       25-49
# 4       25-49
#         ...
# 2751    50-64
# 2752    50-64
# 2753    50-64
# 2754    50-64
# 2755    50-64
# Name: Age, Length: 2756, dtype: object

# %%
df_phof.columns.values.tolist()
# Out:
# ['Month',
#  'Quarter',
#  'Region_Code',
#  'Region_Name',
#  'Parent_Name',
#  'Org_ONS_Code',
#  'Org_Code',
#  'Org_Name',
#  'Age',
#  'Eligible',
#  'Screened',
#  'Coverage(%)',
#  'No. screens to reach target',
#  'National Rank',
#  'Total_Orgs',
#  'National_Coverage(%)',
#  'Coverage_Change']

# %%
df_phof.Month
# Out:
# 0       2021-06-30
# 1       2021-06-30
# 2       2021-06-30
# 3       2021-06-30
# 4       2021-06-30
#            ...
# 2751    2024-06-30
# 2752    2024-06-30
# 2753    2024-06-30
# 2754    2024-06-30
# 2755    2024-06-30
# Name: Month, Length: 2756, dtype: object

# %%
df_phof[['Month', 'Age']].head(10)
# Out:
#         Month    Age
# 0  2021-06-30  25-49
# 1  2021-06-30  25-49
# 2  2021-06-30  25-49
# 3  2021-06-30  25-49
# 4  2021-06-30  25-49
# 5  2021-06-30  25-49
# 6  2021-06-30  25-49
# 7  2021-06-30  25-49
# 8  2021-06-30  25-49
# 9  2021-06-30  25-49

# %%
maindf = df_phof[['Month', 'Region_Name', 'Age', 'Eligible', 'Screened' , 'Coverage(%)',
 'No. screens to reach target']]

# %% [markdown]
# #### Condensed to select categories

# %%
maindf
# Out:
#            Month               Region_Name    Age  Eligible  Screened  \
# 0     2021-06-30  North East and Yorkshire  25-49     42073     32011
# 1     2021-06-30           East of England  25-49     47828     35815
# 2     2021-06-30  North East and Yorkshire  25-49     18051     13355
# 3     2021-06-30                South West  25-49    152746    112441
# 4     2021-06-30           East of England  25-49    189351    128404
# ...          ...                       ...    ...       ...       ...
# 2751  2024-06-30  North East and Yorkshire  50-64     21415     16255
# 2752  2024-06-30  North East and Yorkshire  50-64     35935     27080
# 2753  2024-06-30  North East and Yorkshire  50-64     69205     52270
# 2754  2024-06-30  North East and Yorkshire  50-64     52100     38710
# 2755  2024-06-30  North East and Yorkshire  50-64     39735     31045
#
#       Coverage(%)  No. screens to reach target
# 0       76.084425                         1648
# ...

# %%
pd.options.mode.copy_on_write = True

# %%
# convert 'Month' to date time format
maindf['Month'] = pd.to_datetime(maindf['Month'])

# %% [markdown]
# ### All years: Min and max

# %%
maindf.describe(include='all')
# Out:
#                                 Month Region_Name    Age       Eligible  \
# count                            2756        2756   2756    2756.000000
# unique                            NaN           7      2            NaN
# top                               NaN  North West  25-49            NaN
# freq                              NaN         702   1378            NaN
# mean    2022-12-30 05:32:18.461538304         NaN    NaN   75048.531205
# min               2021-06-30 00:00:00         NaN    NaN   10832.000000
# 25%               2022-03-31 00:00:00         NaN    NaN   26993.750000
# 50%               2022-12-31 00:00:00         NaN    NaN   48380.500000
# 75%               2023-09-30 00:00:00         NaN    NaN   92093.000000
# max               2024-06-30 00:00:00         NaN    NaN  612170.000000
# std                               NaN         NaN    NaN   81466.215679
#
#              Screened  Coverage(%)  No. screens to reach target
# ...

# %% [markdown]
# #### All years: Max eligible

# %%
max_row_all = maindf[maindf['Eligible'] == maindf['Eligible'].max()]
max_row_all[[ 'Month', 'Region_Name',  'Age', 'Eligible', 'Screened', 'Coverage(%)', 'No. screens to reach target']]
# Out:
#           Month Region_Name    Age  Eligible  Screened  Coverage(%)  \
# 2196 2023-12-31      London  25-49    612170    337470    55.126844
#
#       No. screens to reach target
# 2196                       152266

# %% [markdown]
# #### All years: Min eligible

# %%
min_row_all = maindf[maindf['Eligible'] == maindf['Eligible'].min()]
min_row_all[[ 'Month', 'Region_Name',  'Age', 'Eligible', 'Screened', 'Coverage(%)', 'No. screens to reach target']]
# Out:
#          Month Region_Name    Age  Eligible  Screened  Coverage(%)  \
# 206 2021-06-30  North West  50-64     10832      8350    77.086411
#
#      No. screens to reach target
# 206                          316

# %% [markdown]
# #### All years: Max coverage

# %%
max_row_all_coverage = maindf[maindf['Coverage(%)'] == maindf['Coverage(%)'].max()]
max_row_all_coverage[[ 'Month', 'Region_Name',  'Age', 'Eligible', 'Screened', 'Coverage(%)', 'No. screens to reach target']]
# Out:
#          Month Region_Name    Age  Eligible  Screened  Coverage(%)  \
# 176 2021-06-30    Midlands  50-64     92003     72685    79.002859
#
#      No. screens to reach target
# 176                          918

# %% [markdown]
# #### All years: Min coverage

# %%
min_row_all_coverage = maindf[maindf['Coverage(%)'] == maindf['Coverage(%)'].min()]
min_row_all_coverage[[ 'Month', 'Region_Name',  'Age', 'Eligible', 'Screened', 'Coverage(%)', 'No. screens to reach target']]
# Out:
#           Month Region_Name    Age  Eligible  Screened  Coverage(%)  \
# 1984 2023-09-30      London  25-49    605640    330360    54.547256
#
#       No. screens to reach target
# 1984                       154152

# %% [markdown]
# #### All years: Mean coverage: 25-49

# %%
# select '25-49' rows
all_25_49 = maindf[maindf['Age'] == '25-49']
all_25_49
# Out:
#           Month               Region_Name    Age  Eligible  Screened  \
# 0    2021-06-30  North East and Yorkshire  25-49     42073     32011
# 1    2021-06-30           East of England  25-49     47828     35815
# 2    2021-06-30  North East and Yorkshire  25-49     18051     13355
# 3    2021-06-30                South West  25-49    152746    112441
# 4    2021-06-30           East of England  25-49    189351    128404
# ...         ...                       ...    ...       ...       ...
# 2645 2024-06-30  North East and Yorkshire  25-49     35605     24980
# 2646 2024-06-30  North East and Yorkshire  25-49     65650     47190
# 2647 2024-06-30  North East and Yorkshire  25-49    166415    110715
# 2648 2024-06-30  North East and Yorkshire  25-49    110605     70980
# 2649 2024-06-30  North East and Yorkshire  25-49     75390     51830
#
#       Coverage(%)  No. screens to reach target
# 0       76.084425                         1648
# ...

# %%
# store '25-49' coverage
coverage_all_25_49 = all_25_49[['Coverage(%)']]
coverage_all_25_49
# Out:
#       Coverage(%)
# 0       76.084425
# 1       74.882914
# 2       73.984821
# 3       73.613057
# 4       67.812686
# ...           ...
# 2645    70.158686
# 2646    71.881188
# 2647    66.529459
# 2648    64.174314
# 2649    68.749171
#
# [1378 rows x 1 columns]

# %% [markdown]
# ##### Result

# %%
# mean
mean_coverage_all_25_49 = coverage_all_25_49.mean()
mean_coverage_all_25_49
# Out:
# Coverage(%)    69.935293
# dtype: float64

# %% [markdown]
# #### All years: Mean coverage: 50-64

# %%
# select '50-64' rows
all_50_64 = maindf[maindf['Age'] == '50-64']
all_50_64
# Out:
#           Month               Region_Name    Age  Eligible  Screened  \
# 106  2021-06-30  North East and Yorkshire  50-64     25012     19338
# 107  2021-06-30           East of England  50-64     25074     19074
# 108  2021-06-30  North East and Yorkshire  50-64     11644      8873
# 109  2021-06-30                South West  50-64     90880     69636
# 110  2021-06-30           East of England  50-64     85987     64024
# ...         ...                       ...    ...       ...       ...
# 2751 2024-06-30  North East and Yorkshire  50-64     21415     16255
# 2752 2024-06-30  North East and Yorkshire  50-64     35935     27080
# 2753 2024-06-30  North East and Yorkshire  50-64     69205     52270
# 2754 2024-06-30  North East and Yorkshire  50-64     52100     38710
# 2755 2024-06-30  North East and Yorkshire  50-64     39735     31045
#
#       Coverage(%)  No. screens to reach target
# 106     77.314889                          672
# ...

# %%
# store '50-64' coverage
coverage_all_50_64 = all_50_64[['Coverage(%)']]
coverage_all_50_64
# Out:
#       Coverage(%)
# 106     77.314889
# 107     76.070830
# 108     76.202336
# 109     76.624120
# 110     74.457767
# ...           ...
# 2751    75.904740
# 2752    75.358286
# 2753    75.529225
# 2754    74.299424
# 2755    78.130112
#
# [1378 rows x 1 columns]

# %% [markdown]
# ##### Result

# %%
# mean
mean_coverage_all_50_64 = coverage_all_50_64.mean()
mean_coverage_all_50_64
# Out:
# Coverage(%)    75.114132
# dtype: float64

# %% [markdown]
# ### Selection by year: 2021

# %%
# conditional: select maindf > select 'Month' in maindf where the year == 2021
maindf_2021 = maindf[maindf['Month'].dt.year == 2021]

# %%
maindf_2021
# Out:
#          Month               Region_Name    Age  Eligible  Screened  \
# 0   2021-06-30  North East and Yorkshire  25-49     42073     32011
# 1   2021-06-30           East of England  25-49     47828     35815
# 2   2021-06-30  North East and Yorkshire  25-49     18051     13355
# 3   2021-06-30                South West  25-49    152746    112441
# 4   2021-06-30           East of England  25-49    189351    128404
# ..         ...                       ...    ...       ...       ...
# 631 2021-12-31                  Midlands  50-64     35721     27730
# 632 2021-12-31           East of England  50-64     25065     19393
# 633 2021-12-31                South East  50-64     86317     64914
# 634 2021-12-31                North West  50-64     29628     22094
# 635 2021-12-31                North West  50-64     32847     23951
#
#      Coverage(%)  No. screens to reach target
# 0      76.084425                         1648
# 1      74.882914                         2448
# ...

# %%
maindf_2021.describe(include='all')
# Out:
#                       Month Region_Name    Age       Eligible       Screened  \
# count                   636         636    636     636.000000     636.000000
# unique                  NaN           7      2            NaN            NaN
# top                     NaN  North West  25-49            NaN            NaN
# freq                    NaN         162    318            NaN            NaN
# mean    2021-09-30 00:00:00         NaN    NaN   73618.583333   52076.963836
# min     2021-06-30 00:00:00         NaN    NaN   10832.000000    8350.000000
# 25%     2021-06-30 00:00:00         NaN    NaN   26858.000000   19461.500000
# 50%     2021-09-30 00:00:00         NaN    NaN   47602.000000   35637.500000
# 75%     2021-12-31 00:00:00         NaN    NaN   89032.000000   64463.250000
# max     2021-12-31 00:00:00         NaN    NaN  581295.000000  320906.000000
# std                     NaN         NaN    NaN   79574.719916   50722.974807
#
# ...

# %% [markdown]
# #### 2021 max eligible

# %%
# store max row in variable
max_row_2021 = maindf_2021[maindf_2021['Eligible'] == maindf_2021['Eligible'].max()]
# show max row
max_row_2021[[ 'Region_Name',  'Age', 'Eligible', 'Screened', 'Coverage(%)', 'No. screens to reach target']]
# Out:
#     Region_Name    Age  Eligible  Screened  Coverage(%)  \
# 490      London  25-49    581295    320906     55.20536
#
#      No. screens to reach target
# 490                       144130

# %% [markdown]
# #### 2021 min eligible

# %%
# store min row in variable
min_row_2021 = maindf_2021[maindf_2021['Eligible'] == maindf_2021['Eligible'].min()]
# show min row
min_row_2021[[ 'Region_Name',  'Age', 'Eligible', 'Screened', 'Coverage(%)', 'No. screens to reach target']]
# Out:
#     Region_Name    Age  Eligible  Screened  Coverage(%)  \
# 206  North West  50-64     10832      8350    77.086411
#
#      No. screens to reach target
# 206                          316

# %% [markdown]
# ### Selection by year: 2022

# %%
maindf_2022 = maindf[maindf['Month'].dt.year == 2022]

# %%
maindf_2022
# Out:
#           Month               Region_Name    Age  Eligible  Screened  \
# 636  2022-03-31  North East and Yorkshire  25-49     42216     31846
# 637  2022-03-31           East of England  25-49     48017     35716
# 638  2022-03-31  North East and Yorkshire  25-49     18307     13491
# 639  2022-03-31                South West  25-49    153902    112108
# 640  2022-03-31           East of England  25-49    192791    129214
# ...         ...                       ...    ...       ...       ...
# 1479 2022-12-31  North East and Yorkshire  50-64     21201     16264
# 1480 2022-12-31  North East and Yorkshire  50-64     35774     27327
# 1481 2022-12-31  North East and Yorkshire  50-64     68507     51712
# 1482 2022-12-31  North East and Yorkshire  50-64     51536     38156
# 1483 2022-12-31  North East and Yorkshire  50-64     39267     30705
#
#       Coverage(%)  No. screens to reach target
# 636     75.435854                         1927
# ...

# %%
maindf_2022.describe(include='all')
# Out:
#                       Month Region_Name    Age       Eligible       Screened  \
# count                   848         848    848     848.000000     848.000000
# unique                  NaN           7      2            NaN            NaN
# top                     NaN  North West  25-49            NaN            NaN
# freq                    NaN         216    424            NaN            NaN
# mean    2022-08-15 06:00:00         NaN    NaN   74583.676887   52255.774764
# min     2022-03-31 00:00:00         NaN    NaN   11062.000000    8481.000000
# 25%     2022-06-07 06:00:00         NaN    NaN   26972.250000   19750.250000
# 50%     2022-08-15 00:00:00         NaN    NaN   48176.500000   35553.500000
# 75%     2022-10-23 00:00:00         NaN    NaN   90982.750000   65410.000000
# max     2022-12-31 00:00:00         NaN    NaN  594966.000000  328944.000000
# std                     NaN         NaN    NaN   80741.129704   51053.580506
#
# ...

# %% [markdown]
# #### 2022 max eligible

# %%
# store max row in variable
max_row_2022 = maindf_2022[maindf_2022['Eligible'] == maindf_2022['Eligible'].max()]
# show max row
max_row_2022[[ 'Region_Name',  'Age', 'Eligible', 'Screened', 'Coverage(%)', 'No. screens to reach target']]
# Out:
#      Region_Name    Age  Eligible  Screened  Coverage(%)  \
# 1348      London  25-49    594966    325388    54.690184
#
#       No. screens to reach target
# 1348                       150585

# %% [markdown]
# #### 2022 min eligible

# %%
# store min row in variable
min_row_2022 = maindf_2022[maindf_2022['Eligible'] == maindf_2022['Eligible'].min()]
# show min row
min_row_2022[[ 'Region_Name',  'Age', 'Eligible', 'Screened', 'Coverage(%)', 'No. screens to reach target']]
# Out:
#     Region_Name    Age  Eligible  Screened  Coverage(%)  \
# 842  North West  50-64     11062      8481    76.667872
#
#      No. screens to reach target
# 842                          369

# %% [markdown]
# ### Selection by year: 2023

# %%
maindf_2023 = maindf[maindf['Month'].dt.year == 2023]
maindf_2023
# Out:
#           Month               Region_Name    Age  Eligible  Screened  \
# 1484 2023-03-31                South West  25-49    155576    111251
# 1485 2023-03-31           East of England  25-49    198991    129833
# 1486 2023-03-31                  Midlands  25-49    275716    167529
# 1487 2023-03-31                  Midlands  25-49    217576    141442
# 1488 2023-03-31                South West  25-49    193139    135148
# ...         ...                       ...    ...       ...       ...
# 2327 2023-12-31  North East and Yorkshire  50-64     21305     16225
# 2328 2023-12-31  North East and Yorkshire  50-64     35905     27225
# 2329 2023-12-31  North East and Yorkshire  50-64     69030     52160
# 2330 2023-12-31  North East and Yorkshire  50-64     51970     38600
# 2331 2023-12-31  North East and Yorkshire  50-64     39605     30930
#
#       Coverage(%)  No. screens to reach target
# 1484    71.509102                        13210
# ...

# %%
maindf_2023.describe(include='all')
# Out:
#                       Month Region_Name    Age       Eligible       Screened  \
# count                   848         848    848     848.000000     848.000000
# unique                  NaN           7      2            NaN            NaN
# top                     NaN  North West  25-49            NaN            NaN
# freq                    NaN         216    424            NaN            NaN
# mean    2023-08-15 06:00:00         NaN    NaN   75845.601415   52795.242925
# min     2023-03-31 00:00:00         NaN    NaN   11296.000000    8625.000000
# 25%     2023-06-07 06:00:00         NaN    NaN   27102.250000   19923.500000
# 50%     2023-08-15 00:00:00         NaN    NaN   48730.000000   35836.500000
# 75%     2023-10-23 00:00:00         NaN    NaN   93597.750000   66366.250000
# max     2023-12-31 00:00:00         NaN    NaN  612170.000000  337470.000000
# std                     NaN         NaN    NaN   82629.093262   51800.219685
#
# ...

# %% [markdown]
# #### 2023 max eligible

# %%
# store max row in variable
max_row_2023 = maindf_2023[maindf_2023['Eligible'] == maindf_2023['Eligible'].max()]
# show max row
max_row_2023[[ 'Region_Name',  'Age', 'Eligible', 'Screened', 'Coverage(%)', 'No. screens to reach target']]
# Out:
#      Region_Name    Age  Eligible  Screened  Coverage(%)  \
# 2196      London  25-49    612170    337470    55.126844
#
#       No. screens to reach target
# 2196                       152266

# %% [markdown]
# #### 2023 min eligible

# %%
# store min row in variable
min_row_2023 = maindf_2023[maindf_2023['Eligible'] == maindf_2023['Eligible'].min()]
# show min row
min_row_2023[[ 'Region_Name',  'Age', 'Eligible', 'Screened', 'Coverage(%)', 'No. screens to reach target']]
# Out:
#      Region_Name    Age  Eligible  Screened  Coverage(%)  \
# 1644  North West  50-64     11296      8627    76.372167
#
#       No. screens to reach target
# 1644                          410

# %% [markdown]
# ### Selection by year: 2024

# %%
maindf_2024 = maindf[maindf['Month'].dt.year == 2024]
maindf_2024
# Out:
#           Month               Region_Name    Age  Eligible  Screened  \
# 2332 2024-03-31                South West  25-49    157430    113345
# 2333 2024-03-31           East of England  25-49    206400    134650
# 2334 2024-03-31                  Midlands  25-49    285180    173410
# 2335 2024-03-31                  Midlands  25-49    224775    148265
# 2336 2024-03-31                South West  25-49    197885    137685
# ...         ...                       ...    ...       ...       ...
# 2751 2024-06-30  North East and Yorkshire  50-64     21415     16255
# 2752 2024-06-30  North East and Yorkshire  50-64     35935     27080
# 2753 2024-06-30  North East and Yorkshire  50-64     69205     52270
# 2754 2024-06-30  North East and Yorkshire  50-64     52100     38710
# 2755 2024-06-30  North East and Yorkshire  50-64     39735     31045
#
#       Coverage(%)  No. screens to reach target
# 2332    71.997078                        12599
# ...

# %%
maindf_2024.describe(include='all')
# Out:
#                       Month Region_Name    Age       Eligible       Screened  \
# count                   424         424    424     424.000000     424.000000
# unique                  NaN           7      2            NaN            NaN
# top                     NaN  North West  25-49            NaN            NaN
# freq                    NaN         108    212            NaN            NaN
# mean    2024-05-15 12:00:00         NaN    NaN   76529.021226   53414.540094
# min     2024-03-31 00:00:00         NaN    NaN   11400.000000    8655.000000
# 25%     2024-03-31 00:00:00         NaN    NaN   27107.500000   19711.250000
# 50%     2024-05-15 12:00:00         NaN    NaN   49107.500000   36242.500000
# 75%     2024-06-30 00:00:00         NaN    NaN   94196.250000   66747.500000
# max     2024-06-30 00:00:00         NaN    NaN  611695.000000  340530.000000
# std                     NaN         NaN    NaN   83591.372390   52768.792996
#
# ...

# %% [markdown]
# #### 2024 max eligible

# %%
# store max row in variable
max_row_2024 = maindf_2024[maindf_2024['Eligible'] == maindf_2024['Eligible'].max()]
# show max row
max_row_2024[[ 'Region_Name',  'Age', 'Eligible', 'Screened', 'Coverage(%)', 'No. screens to reach target']]
# Out:
#      Region_Name    Age  Eligible  Screened  Coverage(%)  \
# 2408      London  25-49    611695    340530    55.669901
#
#       No. screens to reach target
# 2408                       148826

# %% [markdown]
# #### 2024 min eligible

# %%
# store min row in variable
min_row_2024 = maindf_2024[maindf_2024['Eligible'] == maindf_2024['Eligible'].min()]
# show min row
min_row_2024[[ 'Region_Name',  'Age', 'Eligible', 'Screened', 'Coverage(%)', 'No. screens to reach target']]
# Out:
#      Region_Name    Age  Eligible  Screened  Coverage(%)  \
# 2492  North West  50-64     11400      8655    75.921053
#
#       No. screens to reach target
# 2492                          465
